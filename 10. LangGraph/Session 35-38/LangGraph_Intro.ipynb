# %%
#pip install langgraph

# %%
pip show langgraph
# Out:
# Name: langgraph
# Version: 1.0.9
# Summary: Building stateful, multi-actor applications with LLMs
# Home-page: https://docs.langchain.com/oss/python/langgraph/overview
# Author:
# Author-email:
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph-sdk, pydantic, xxhash
# Required-by: langchain

# %%
from langgraph.graph import StateGraph, MessagesState, START, END

# %%
graph = StateGraph(MessagesState)

# %%
def mock_llm(state: MessagesState):
    return {"messages": [{"role": "ai", "content": "hello world"}]}

def node2(state: MessagesState):
    return {"messages": [{"role": "ai", "content": "Node2"}]}

def node3(state: MessagesState):
    return {"messages": [{"role": "ai", "content": "Node3"}]}

# %%
graph.add_node(mock_llm)
graph.add_node(node2)
graph.add_node(node3)

# %%
graph.add_edge(START, "mock_llm")
graph.add_edge("mock_llm", "node2")
graph.add_edge("mock_llm", "node3")
graph.add_edge("node2", END)
graph.add_edge("node3", END)

# %%
graph = graph.compile()

# %%
graph.invoke({"messages": [{"role": "user", "content": "hi!"}]})
# Out:
# {'messages': [HumanMessage(content='hi!', additional_kwargs={}, response_metadata={}, id='aab605a4-cec8-4330-bbf6-76acc06afb47'),
#   AIMessage(content='hello world', additional_kwargs={}, response_metadata={}, id='812ed9cc-95cd-41ce-bfa6-7609314d26a0', tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content='Node2', additional_kwargs={}, response_metadata={}, id='a5362768-0b25-419a-8f3e-99643bfc812b', tool_calls=[], invalid_tool_calls=[]),
#   AIMessage(content='Node3', additional_kwargs={}, response_metadata={}, id='9503098d-e285-4859-97e0-e53092564d0c', tool_calls=[], invalid_tool_calls=[])]}
